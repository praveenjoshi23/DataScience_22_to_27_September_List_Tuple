# %%
# !pip install requests

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen as uReq

# %%
import logging

# %%
flip_url="https://www.flipkart.com/search?q="+"iphone12pro"

# %%
flip_url
# Out:
# 'https://www.flipkart.com/search?q=iphone12pro'

# %%
urlclient=uReq(flip_url)

# %%
flip_page=urlclient.read()    #Storing DataDump in a Variable

# %%
flip_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.09b0e9.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
flip_html=bs(flip_page,'html.parser')      #beautifying page

# %%
flip_html
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# # Finding particular data in variable flip_html containing data dump

# %%
flip_html.find("div",{"class":"_2kHMtA"})
# Out:
# <div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-12-pro-graphite-128-gb/p/itm03e5f2595d843?pid=MOBFWBYZBZ7Y56WD&amp;lid=LSTMOBFWBYZBZ7Y56WDLRWIKS&amp;marketplace=FLIPKART&amp;q=iphone12pro&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=bc63c0f7-cfc3-4773-a617-5cb0734bcd8b.MOBFWBYZBZ7Y56WD.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=gezlk3xt7k0000001712053275421&amp;qH=712933e6bd68e7b9" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Apple iPhone 12 Pro (Graphite, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kg8avm80/mobile/u/q/d/apple-iphone-12-pro-dummyapplefsn-original-imafwgbrbzjgug4j.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><lab
# ...

# %%
bigbox=flip_html.findAll("div",{"class":"_2kHMtA"})

# %%
len(bigbox)
# Out:
# 24

# %%
bigbox[0].a
# Out:
# <a class="_1fQZEK" href="/apple-iphone-12-pro-graphite-128-gb/p/itm03e5f2595d843?pid=MOBFWBYZBZ7Y56WD&amp;lid=LSTMOBFWBYZBZ7Y56WDLRWIKS&amp;marketplace=FLIPKART&amp;q=iphone12pro&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=bc63c0f7-cfc3-4773-a617-5cb0734bcd8b.MOBFWBYZBZ7Y56WD.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=gezlk3xt7k0000001712053275421&amp;qH=712933e6bd68e7b9" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Apple iPhone 12 Pro (Graphite, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kg8avm80/mobile/u/q/d/apple-iphone-12-pro-dummyapplefsn-original-imafwgbrbzjgug4j.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><s
# ...

# %%
bigbox[0].a['href']
# Out:
# '/apple-iphone-12-pro-graphite-128-gb/p/itm03e5f2595d843?pid=MOBFWBYZBZ7Y56WD&lid=LSTMOBFWBYZBZ7Y56WDLRWIKS&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=bc63c0f7-cfc3-4773-a617-5cb0734bcd8b.MOBFWBYZBZ7Y56WD.SEARCH&ppt=None&ppn=None&ssid=gezlk3xt7k0000001712053275421&qH=712933e6bd68e7b9'

# %%
"https://www.flipkart.com"+bigbox[0].a['href']  #Appending with root link
# Out:
# 'https://www.flipkart.com/apple-iphone-12-pro-graphite-128-gb/p/itm03e5f2595d843?pid=MOBFWBYZBZ7Y56WD&lid=LSTMOBFWBYZBZ7Y56WDLRWIKS&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=bc63c0f7-cfc3-4773-a617-5cb0734bcd8b.MOBFWBYZBZ7Y56WD.SEARCH&ppt=None&ppn=None&ssid=gezlk3xt7k0000001712053275421&qH=712933e6bd68e7b9'

# %%
#Printing All Product Reviews with for loop

# %%
for i in bigbox:
    print("https://www.flipkart.com"+i.a['href'] )     #Observe this
# Out:
# https://www.flipkart.com/apple-iphone-12-pro-graphite-128-gb/p/itm03e5f2595d843?pid=MOBFWBYZBZ7Y56WD&lid=LSTMOBFWBYZBZ7Y56WDLRWIKS&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=bc63c0f7-cfc3-4773-a617-5cb0734bcd8b.MOBFWBYZBZ7Y56WD.SEARCH&ppt=None&ppn=None&ssid=gezlk3xt7k0000001712053275421&qH=712933e6bd68e7b9
# https://www.flipkart.com/apple-iphone-12-pro-pacific-blue-128-gb/p/itm97c833296c221?pid=MOBFWBYZXYSCEEEH&lid=LSTMOBFWBYZXYSCEEEHLGQLJT&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=bc63c0f7-cfc3-4773-a617-5cb0734bcd8b.MOBFWBYZXYSCEEEH.SEARCH&ppt=None&ppn=None&ssid=gezlk3xt7k0000001712053275421&qH=712933e6bd68e7b9
# ...

# %%
# del bigbox[0:3]   #Remove Forst 3 bigboxes

# %%
'''for i in bigbox:
    print("https://www.flipkart.com"+i.div.div.div.a['href'] ) '''
# Out:
# 'for i in bigbox:\n    print("https://www.flipkart.com"+i.div.div.div.a[\'href\'] )  '

# %%
productlink="https://www.flipkart.com"+bigbox[0].a['href']

# %%
product_req=requests.get(productlink)

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-12-pro-graphite-128-gb/p/itm03e5f2595d843?pid=MOBFWBYZBZ7Y56WD&lid=LSTMOBFWBYZBZ7Y56WDLRWIKS&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=bc63c0f7-cfc3-4773-a617-5cb0734bcd8b.MOBFWBYZBZ7Y56WD.SEARCH&ppt=None&ppn=None&ssid=gezlk3xt7k0000001712053275421&qH=712933e6bd68e7b9'

# %%
product_html=bs(product_req.text,'html.parser')

# %%
product_html.findAll("div",{"class":"col _2wzgFH"})
# Out:
# [<div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Simply awesome</p></div><div class="row"><div class="t-ZTKy"><div><div class="">indeed a great phone feels premium in hand but battery life is low</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202105/blobio-imr-202105_218937a29a45459c9c6f56e264d7c733.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Rajkumar tiwari</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="_2mcZGG" id="review-ff2300b9-29
# ...

# %%
comment_box=product_html.findAll("div",{"class":"col _2wzgFH"})

# %%
len(comment_box)
# Out:
# 10

# %%
comment_box[0]
# Out:
# <div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Simply awesome</p></div><div class="row"><div class="t-ZTKy"><div><div class="">indeed a great phone feels premium in hand but battery life is low</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202105/blobio-imr-202105_218937a29a45459c9c6f56e264d7c733.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Rajkumar tiwari</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="_2mcZGG" id="review-ff2300b9-296
# ...

# %%
comment_box[0].div.find_all("p",{"class":"_2-N8zT"})
# Out:
# [<p class="_2-N8zT">Simply awesome</p>]

# %%
comment_box[0]("p",{"class":"_2sc7ZR _2V5EHH"})
# Out:
# [<p class="_2sc7ZR _2V5EHH">Rajkumar tiwari</p>]

# %%
comment_box[0]("p",{"class":"_2sc7ZR _2V5EHH"})[0]
# Out:
# <p class="_2sc7ZR _2V5EHH">Rajkumar tiwari</p>

# %%
comment_box[0]("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Rajkumar tiwari'

# %%
for i in comment_box:
    print(i.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Rajkumar tiwari
# Tushar Saini
# Aasheesh Vats
# Kirti Yadav
# Pankaj Mahor
# Vinit Kar
# Rahul  Meena
# Salman Rahman
# Anveer arora
# Harsh Singh

# %%
comment_box[0].div.div
# Out:
# <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>

# %%
comment_box[0].div.div.text
# Out:
# '5'

# %%
for i in comment_box:
    print(i.div.div.text)
# Out:
# 5
# 5
# 5
# 3
# 5
# 5
# 5
# 5
# 5
# 5

# %%
#Scrapping Comment Header

# %%
comment_box[0].div.p
# Out:
# <p class="_2-N8zT">Simply awesome</p>

# %%
comment_box[0].div.p.text
# Out:
# 'Simply awesome'

# %%
for i in comment_box:
    print(i.div.p.text)
# Out:
# Simply awesome
# Fabulous!
# Fabulous!
# Nice
# Awesome
# Best in the market!
# Highly recommended
# Fabulous!
# Awesome
# Classy product

# %%
comment_box[0].find_all("div",{"class":""})
# Out:
# [<div><div class="">indeed a great phone feels premium in hand but battery life is low</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">indeed a great phone feels premium in hand but battery life is low</div>,
#  <div></div>]

# %%
comment_box[0].find_all("div",{"class":""})[0]
# Out:
# <div><div class="">indeed a great phone feels premium in hand but battery life is low</div><span class="_1H-bmy"><span>READ MORE</span></span></div>

# %%
comment_box[0].find_all("div",{"class":""})[0].div
# Out:
# <div class="">indeed a great phone feels premium in hand but battery life is low</div>

# %%
comment_box[0].find_all("div",{"class":""})[0].div.text
# Out:
# 'indeed a great phone feels premium in hand but battery life is low'

# %%
for i in comment_box:
    print(i.find_all("div",{"class":""})[0].div.text)
# Out:
# indeed a great phone feels premium in hand but battery life is low
# The camera is mind-blowing I love it 😘
# A masterpiece to cherish.
# Its just Perfect . Prices are a bit high .
# Best designed iPhone
# I have been using iPhones for years, but the fast charging and battery on this one is brilliant. Like i always say, iPhone is more of a jewellery than a phone. But this one has some power-packed features and an awesome camera. So if you can afford it, buy it!
# I like the most in this phone:-1. I like the size of this phone because it is easy to hold.2. The camera quality of this phone is admirable. 3. Battery backup is good.4. The new design and colour  of this phone also a plus point of its beauty.5. These  points are my personal which i like most in this phone.
# This one of the best iPhone ever built, though battery backup isn’t good. But the user experience is brilliant.Upgraded from 11 Pro.
# ...
