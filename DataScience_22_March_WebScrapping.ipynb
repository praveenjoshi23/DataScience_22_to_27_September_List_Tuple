# %%
# !pip install requests

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen as uReq

# %%
import logging

# %%
flip_url="https://www.flipkart.com/search?q="+"iphone12pro"

# %%
flip_url
# Out:
# 'https://www.flipkart.com/search?q=iphone12pro'

# %%
urlclient=uReq(flip_url)

# %%
flip_page=urlclient.read()    #Storing DataDump in a Variable

# %%
flip_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.09b0e9.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
flip_html=bs(flip_page,'html.parser')      #deautifying page

# %%
"https://www.flipkart.com"+"/apple-iphone-12-pro-graphite-128-gb/p/itm03e5f2595d843?pid=MOBFWBYZBZ7Y56WD&lid=LSTMOBFWBYZBZ7Y56WDLRWIKS&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=481f09d2-fdd2-40f6-8eb6-c9394d48565a.MOBFWBYZBZ7Y56WD.SEARCH&ppt=sp&ppn=sp&ssid=cnukielfeo0000001711261062798&qH=712933e6bd68e7b9"
# Out:
# 'https://www.flipkart.com/apple-iphone-12-pro-graphite-128-gb/p/itm03e5f2595d843?pid=MOBFWBYZBZ7Y56WD&lid=LSTMOBFWBYZBZ7Y56WDLRWIKS&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=481f09d2-fdd2-40f6-8eb6-c9394d48565a.MOBFWBYZBZ7Y56WD.SEARCH&ppt=sp&ppn=sp&ssid=cnukielfeo0000001711261062798&qH=712933e6bd68e7b9'

# %% [markdown]
# # Finding particular data in variable flip_html containing data dump

# %%
bigbox=flip_html.findAll("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 29

# %%
bigbox[3].div.div.div.a['href']       #We got href link for product
# Out:
# '/apple-iphone-12-pro-max-pacific-blue-128-gb/p/itmd89812b558a03?pid=MOBFWBYZZABKHZQA&lid=LSTMOBFWBYZZABKHZQACQ9MLL&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=de007c06-5d54-4f2f-bfbc-4f4159d14dd4.MOBFWBYZZABKHZQA.SEARCH&ppt=None&ppn=None&ssid=nq8c0du5s00000001711369138794&qH=712933e6bd68e7b9'

# %%
"https://www.flipkart.com"+bigbox[3].div.div.div.a['href']  #Appending with root link
# Out:
# 'https://www.flipkart.com/apple-iphone-12-pro-max-pacific-blue-128-gb/p/itmd89812b558a03?pid=MOBFWBYZZABKHZQA&lid=LSTMOBFWBYZZABKHZQACQ9MLL&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=de007c06-5d54-4f2f-bfbc-4f4159d14dd4.MOBFWBYZZABKHZQA.SEARCH&ppt=None&ppn=None&ssid=nq8c0du5s00000001711369138794&qH=712933e6bd68e7b9'

# %%
#Printing All Product Reviews with for loop

# %%
for i in bigbox:
    print("https://www.flipkart.com"+i.div.div.div.a['href'] )     #Observe this
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [19], line 2
#       1 for i in bigbox:
# ----> 2     print("https://www.flipkart.com"+i.div.div.div.a['href'] )     #Observe this
#
# TypeError: 'NoneType' object is not subscriptable

# %%
del bigbox[0:3]   #Remove Forst 3 bigboxes

# %%
for i in bigbox:
    print("https://www.flipkart.com"+i.div.div.div.a['href'] )
# Out:
# https://www.flipkart.com/apple-iphone-12-pro-max-pacific-blue-128-gb/p/itmd89812b558a03?pid=MOBFWBYZZABKHZQA&lid=LSTMOBFWBYZZABKHZQACQ9MLL&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=de007c06-5d54-4f2f-bfbc-4f4159d14dd4.MOBFWBYZZABKHZQA.SEARCH&ppt=None&ppn=None&ssid=nq8c0du5s00000001711369138794&qH=712933e6bd68e7b9
# https://www.flipkart.com/apple-iphone-12-pro-pacific-blue-256-gb/p/itmea897274baa30?pid=MOBFWBYZVRPH2UCD&lid=LSTMOBFWBYZVRPH2UCDHPQUAR&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=de007c06-5d54-4f2f-bfbc-4f4159d14dd4.MOBFWBYZVRPH2UCD.SEARCH&ppt=None&ppn=None&ssid=nq8c0du5s00000001711369138794&qH=712933e6bd68e7b9
# ...

# %%
productlink="https://www.flipkart.com"+bigbox[4].div.div.div.a['href']

# %%
product_req=requests.get(productlink)

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-12-pro-max-gold-256-gb/p/itm1e0354f5bbc8c?pid=MOBFWBYZZPW8JHQF&lid=LSTMOBFWBYZZPW8JHQF9DJLT1&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_6&otracker=search&fm=organic&iid=de007c06-5d54-4f2f-bfbc-4f4159d14dd4.MOBFWBYZZPW8JHQF.SEARCH&ppt=None&ppn=None&ssid=nq8c0du5s00000001711369138794&qH=712933e6bd68e7b9'

# %%
product_html=bs(product_req.text,'html.parser')

# %%
product_html.find_all("div",{"class":"_16PBlm"})
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Simply awesome</p></div><div class="row"><div class="t-ZTKy"><div><div class="">indeed a great phone feels premium in hand but battery life is low</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202105/blobio-imr-202105_218937a29a45459c9c6f56e264d7c733.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Rajkumar tiwari</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p 
# ...

# %%
comment_box=product_html.find_all("div",{"class":"_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})
# Out:
# [<p class="_2sc7ZR _2V5EHH">Rajkumar tiwari</p>]

# %%
comment_box[0].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0]
# Out:
# <p class="_2sc7ZR _2V5EHH">Rajkumar tiwari</p>

# %%
comment_box[0].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Rajkumar tiwari'

# %%
for i in comment_box:
    print(i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Rajkumar tiwari
# Tushar Saini
# Aasheesh Vats
# Pankaj Mahor
# Vinit Kar
# Rahul  Meena
# Salman Rahman
# Anveer arora
# Harsh Singh
# Rohit Unia
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [48], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'
